# %% [markdown]
# ## Example of document clustering using movie plots

# %%
import numpy as np
import pandas as pd
import nltk
import re
import os
import codecs
from sklearn import feature_extraction
import mpld3

# %% [markdown]
# ### 1. Read input data with a selection of movies

# %%
os.chdir(r'C:\Users\CAS85405\Desktop\Movie_plots')
input_data = pd.read_csv('Sample.csv',index_col=0)
input_data
# Out:
#                                   Title  \
# 1                            Paddington
# 2                      Mr. & Mrs. Smith
# 3                How to Steal a Million
# 4                           Scary Movie
# 5                           Monte Carlo
# 6                   Father of the Bride
# 7                            Parenthood
# 8                       Treasure Island
# 9                  Mutiny on the Bounty
# 10                     Long John Silver
# 11         The Adventures of Marco Polo
# 12                    The Monuments Men
# 13                    Against All Flags
# 14                       Vertical Limit
# 15                      Above Suspicion
# 16                              Susie Q
# 17                   Night and the City
# 18                 Grand Theft Auto III
# 19                       The Super Cops
# 20  Grand Theft Auto: Vice City Stories
#
#                                                  Plot     Tag
# 1   An explorer named Montgomery Clyde (Tim Downie...  comedy
# 2   DAVID and ANN SMITH have a volatile marriage, ...  comedy
# 3   Paris, 1966...Monsieur Charles Bonnet (Hugh Gr...  comedy
# 4   Teenager Drew Decker is home alone when she re...  comedy
# 5   The film begins with 18-year old Grace Ann Ben...  comedy
# 6   George Banks (Steve Martin) is the owner of an...  comedy
# 7   Gil Buckman (Steve Martin) is a 35 year-old fa...  comedy
# 8   Young Jim Hawkins Jackie Cooper) and his mothe...  action
# 9   One night in Portsmouth, England in 1787, a pr...  action
# 10  The movie is set some time after the events of...  action
# 11  Nicolo Polo shows treasures from China and sen...  action
# 12  In 1943, the Allies are making good progress d...  action
# 13  Brian Hawke, an officer aboard the British mer...  action
# 14  In a mountain range in the Southwestern United...  action
# 15  In the spring of 1939 in England, Oxford Unive...    noir
# 16  In the fictional town of Willow Valley, Washin...    noir
# 17  Harry Fabian (Widmark) is an ambitious America...    noir
# 18  While robbing a bank in Liberty City, ambitiou...    noir
# 19  The film opens with archival footage from a pr...    noir
# 20  U.S. Army Corporal Victor "Vic" Vance had an i...    noir

# %% [markdown]
# ### 2. Load stopwords to be ignored

# %%
# load nltk's English stopwords as variable called 'stopwords'
stopwords = nltk.corpus.stopwords.words('english')
print (stopwords[:10])
# Out:
# ['i', 'me', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you', "you're"]

# %% [markdown]
# ### 3. Tokenize and stem
#
# #### <span style="color:red">Tokenize:</span><br>
# > split the plot text into a list of its respective words (or tokens)
# #### <span style="color:red">Stem:</span><br>
# > map different forms of the same word to a common "stem" (example: connection, connective, connected -> **connect**)

# %%
#Define a tokenizer and stemmer which returns the set of stems in the text that it is passed

from nltk.stem.snowball import SnowballStemmer
stemmer = SnowballStemmer("english")

def tokenize_and_stem(text):
    # first tokenize by sentence, then by word to ensure that punctuation is caught as its own token
    tokens = [word for sent in nltk.sent_tokenize(text) for word in nltk.word_tokenize(sent)]
    filtered_tokens = []
    # filter out any tokens not containing letters (e.g., numeric tokens, raw punctuation)
    for token in tokens:
        if re.search('[a-zA-Z]', token):
            filtered_tokens.append(token)
    stems = [stemmer.stem(t) for t in filtered_tokens]
    return stems


def tokenize_only(text):
    # first tokenize by sentence, then by word to ensure that punctuation is caught as its own token
    tokens = [word.lower() for sent in nltk.sent_tokenize(text) for word in nltk.word_tokenize(sent)]
    filtered_tokens = []
    # filter out any tokens not containing letters (e.g., numeric tokens, raw punctuation)
    for token in tokens:
        if re.search('[a-zA-Z]', token):
            filtered_tokens.append(token)
    return filtered_tokens

# %%
#Test
from sklearn.feature_extraction.text import TfidfVectorizer
movie_title = []
movie_words = []

for index, row in input_data.iterrows():
    
    #Grab movie title and plot
    movie_title.append(row['Title']) 
    movie_words.append(row['Plot'])
    
vectorizer = TfidfVectorizer()
X = vectorizer.fit_transform(movie_words)
print(X.shape)
# Out:
# (20, 4322)

# %%
#List of features used in the matrix
print(vectorizer.get_feature_names()[100:110])
# Out:
# ['aghast', 'ago', 'agree', 'agreed', 'agrees', 'ahmed', 'air', 'airport', 'akimbo', 'al']

# %%
#Apply functions to the movie plots

movie_title = []
movie_words = []

for index, row in input.iterrows():
    
    #Grab movie title and plot
    movie_title.append(row['Title']) 
    plot = row['Plot'].split() #From string to list of words: ['I', 'don't', 'know', 'what', 'I', 'am', 'doing']
    
    #Tokenize and stem each plot text
    stemmed = []
    tokenized = []
    
    for word in plot:
        
        #Tokenize and stem
        stemmed_words = tokenize_and_stem(word)
        stemmed.extend(stemmed_words)
        
        #Tokenize only
        tokenized_words = tokenize_only(word)
        tokenized.extend(tokenized_words)
        
        #Store single movie data in a dataframe
        vocabulary = pd.DataFrame({'words': tokenized}, index = stemmed)
        vocabulary.index = vocabulary.index.rename('stems')
        
    #Use movie words to create a flat catalogue of all tokenized words
    movie_words.extend(tokenized) #List of lists

# %%
#movie_words is a list of lists with the tokenized words for each movie plot
movie_words[:100]
# Out:
# ['an',
#  'explorer',
#  'named',
#  'montgomery',
#  'clyde',
#  'tim',
#  'downie',
#  'documents',
#  'his',
#  'trip',
#  'to',
#  'darkest',
#  'peru',
#  'he',
#  'comes',
#  'across',
#  'a',
#  'rather',
#  'intelligent',
#  'species',
#  'of',
#  'bears',
#  'although',
#  'he',
#  'tries',
#  'to',
#  'take',
#  'one',
#  'in',
#  'he',
#  'decides',
#  'to',
#  'bond',
#  'with',
#  'them',
#  'and',
#  'learns',
#  'that',
#  'they',
#  'can',
#  'talk',
#  'and',
#  'have',
#  'a',
#  'great',
#  'appetite',
#  'for',
#  'marmalade',
#  'clyde',
#  'says',
#  'he',
#  "'s",
#  'learned',
#  'a',
#  'lot',
#  'from',
#  'the',
#  'bears',
#  'and',
#  'he',
#  'wonders',
#  'if',
#  'the',
#  'bears',
#  'have',
#  'learned',
#  'anything',
#  'from',
#  'him.years',
#  'later',
#  'a',
#  'young',
#  'bear',
#  'voice',
#  'of',
#  'ben',
#  'whishaw',
#  'awakens',
#  'to',
#  'find',
#  'that',
#  'the',
#  'marmalade',
#  'fruits',
#  'have',
#  'been',
#  'produced',
#  'he',
#  'excitedly',
#  'runs',
#  'to',
#  'his',
#  'aunt',
#  'lucy',
#  'voice',
#  'of',
#  'imelda',
#  'staunton',
#  'and',
#  'uncle']

# %%
#What do tokenize and stem do? Take a look at the vocabulary for a given movie

vocabulary
# Out:
#            words
# stems
# u.           u.s
# armi        army
# corpor  corporal
# victor    victor
# vic          vic
# ...          ...
# origin  original
# game        game
# in            in
# more        more
# detail    detail
#
# [1191 rows x 1 columns]

# %% [markdown]
# ### 4. Document similarity: the <span style="color:red">term frequency</span>-<span style="color:blue">inverse document frequency</span> (<span style="color:red">tf</span>-<span style="color:blue">idf</span>)

# %% [markdown]
# Procedure:

# %% [markdown]
# > 1. Count word occurrences by document (movie plot) <br>
# > 2. Transform this into a document-term matrix (dtm) <br>
# > 3. Apply the term frequency-inverse weighing: higher weight to words that are frequent within a plot but not frequent within all plots (the words has more meaning for a particular movie than it has for all movies)

# %% [markdown]
# <img src="dtm.png" align='left'>

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

input_data = movie_words

#define vectorizer parameters
tfidf_vectorizer = TfidfVectorizer(max_df=0.95, max_features=200000,
                                 min_df=2, stop_words='english', strip_accents = 'ascii', norm='l2',
                                 use_idf=True, tokenizer=tokenize_and_stem, ngram_range=(1,3))

tfidf_matrix = tfidf_vectorizer.fit_transform(input_data) #fit the vectorizer to movie_words

print("Matrix shape:")
print(tfidf_matrix.shape)
# Out:
# C:\Users\CAS85405\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\feature_extraction\text.py:385: UserWarning: Your stop_words may be inconsistent with your preprocessing. Tokenizing the stop words generated tokens ['abov', 'afterward', 'alon', 'alreadi', 'alway', 'ani', 'anoth', 'anyon', 'anyth', 'anywher', 'becam', 'becaus', 'becom', 'befor', 'besid', 'cri', 'describ', 'dure', 'els', 'elsewher', 'empti', 'everi', 'everyon', 'everyth', 'everywher', 'fifti', 'forti', 'henc', 'hereaft', 'herebi', 'howev', 'hundr', 'inde', 'mani', 'meanwhil', 'moreov', 'nobodi', 'noon', 'noth', 'nowher', 'onc', 'onli', 'otherwis', 'ourselv', 'perhap', 'pleas', 'sever', 'sinc', 'sincer', 'sixti', 'someon', 'someth', 'sometim', 'somewher', 'themselv', 'thenc', 'thereaft', 'therebi', 'therefor', 'togeth', 'twelv', 'twenti', 'veri', 'whatev', 'whenc', 'whenev', 'wherea', 'whereaft', 'wherebi', 'wherev', 'whi', 'yourselv'] not in stop_words.
#   'stop_words.' % sorted(inconsistent))
# Matrix shape:
# (20552, 1526)

# %%
v
terms = tfidf_vectorizer.get_feature_names()
terms
# Out:
# ["'d",
#  "'m",
#  "'s",
#  '8-ball',
#  'abandon',
#  'abl',
#  'aboard',
#  'abov',
#  'abus',
#  'accept',
#  'accid',
#  'accident',
#  'accompani',
#  'accus',
#  'acknowledg',
#  'acquaint',
#  'acquir',
#  'act',
#  'actor',
#  'actual',
#  'add',
#  'addit',
#  'adjoin',
#  'admir',
#  'admit',
#  'advanc',
#  'adventur',
#  'advic',
#  'advis',
#  'affair',
#  'afford',
#  'afternoon',
#  'agent',
#  'ago',
#  'agre',
#  'ahm',
#  'air',
#  'airport',
#  'alarm',
#  'alexand',
#  'alicia',
#  'alik',
#  'aliv',
#  'alli',
#  'allow',
#  'alon',
#  'alreadi',
#  'alway',
#  'ambiti',
#  'ambush',
#  'american',
#  'amus',
#  'angel',
#  'anger',
#  'angri',
#  'angrili',
#  'ani',
#  'ann',
#  'anna',
#  'anni',
#  'announc',
#  'anoth',
#  'answer',
#  'anthoni',
#  'antiqu',
#  'anxieti',
#  'anymor',
#  'anyon',
#  'anyth',
#  'apart',
#  'apolog',
#  'appar',
#  'appear',
#  'appoint',
#  'approach',
#  'archiv',
#  'argu',
#  'argument',
#  'arm',
#  'armando',
#  'armi',
#  'arrang',
#  'arrest',
#  'arriv',
#  'arrog',
#  'art',
#  'artist',
#  'artwork',
#  'aschenhausen',
#  'ask',
#  'assassin',
#  'assault',
#  'assembl',
#  'assign',
#  'assist',
#  'asthma',
#  'astonish',
#  'asuka',
#  'attach',
#  'attack',
#  'attempt',
#  'attend',
#  'attent',
#  'auction',
#  'audienc',
#  'aunt',
#  'author',
#  'auto',
#  'avalanch',
#  'avoid',
#  'await',
#  'awaken',
#  'away',
#  'awkward',
#  'b',
#  'babi',
#  'background',
#  'backpack',
#  'bad',
#  'balanc',
#  'balconi',
#  'bank',
#  'banker',
#  'bar',
#  'bare',
#  'barri',
#  'base',
#  'basement',
#  'basil',
#  'basketbal',
#  'bathroom',
#  'baxter',
#  'beach',
#  'beam',
#  'bear',
#  'beaten',
#  'becaus',
#  'becom',
#  'bed',
#  'bedroom',
#  'beer',
#  'befor',
#  'befriend',
#  'beg',
#  'begin',
#  'behavior',
#  'believ',
#  'belong',
#  'belov',
#  'ben',
#  'bend',
#  'benson',
#  'best',
#  'betray',
#  'better',
#  'bicker',
#  'bid',
#  'billi',
#  'bird',
#  'birthday',
#  'bit',
#  'black',
#  'blame',
#  'bligh',
#  'blood',
#  'blow',
#  'board',
#  'boast',
#  'boat',
#  'bobbi',
#  'bodi',
#  'bond',
#  'bone',
#  'bonnet',
#  'book',
#  'booki',
#  'boomerang',
#  'bought',
#  'bounti',
#  'box',
#  'boy',
#  'boyfriend',
#  'bracelet',
#  'brasiliano',
#  'breadfruit',
#  'break',
#  'brenda',
#  'bribe',
#  'bridg',
#  'brief',
#  'bring',
#  'bristol',
#  'british',
#  'brochur',
#  'broken',
#  'brother',
#  'brown',
#  'bruce',
#  'bruge',
#  'brush',
#  'brutal',
#  'bryan',
#  'bucket',
#  'buffi',
#  'build',
#  'bump',
#  'bunch',
#  'burglar',
#  'burn',
#  'busi',
#  'bust',
#  'buy',
#  'buyer',
#  'byam',
#  'ca',
#  'cab',
#  'cabin',
#  'cach',
#  'caller',
#  'calm',
#  'camera',
#  'camp',
#  'campbel',
#  'cannon',
#  'captain',
#  'captur',
#  'car',
#  'care',
#  'career',
#  'carri',
#  'cartel',
#  'carv',
#  'case',
#  'cassidi',
#  'catalina',
#  'catch',
#  'caught',
#  'caus',
#  'cave',
#  'celebr',
#  'cellini',
#  'centuri',
#  'certain',
#  'chair',
#  'chanc',
#  'chang',
#  'charact',
#  'chariti',
#  'charl',
#  'chase',
#  'chateau',
#  'check',
#  'cheer',
#  'chess',
#  'chic',
#  'chief',
#  'child',
#  'children',
#  'china',
#  'chip',
#  'cholo',
#  'choos',
#  'chopper',
#  'christian',
#  'chuck',
#  'chunk',
#  'cigarett',
#  'cindi',
#  'citi',
#  'claim',
#  'clark',
#  'class',
#  'claud',
#  'clean',
#  'clermont',
#  'cliff',
#  'climb',
#  'climber',
#  'close',
#  'closet',
#  'cloth',
#  'club',
#  'clue',
#  'clyde',
#  'coast',
#  'coat',
#  'code',
#  'coin',
#  'cold',
#  'collar',
#  'collect',
#  'collector',
#  'collin',
#  'colonel',
#  'come',
#  'comfort',
#  'command',
#  'commend',
#  'commiss',
#  'compet',
#  'compil',
#  'complain',
#  'complet',
#  'complic',
#  'comput',
#  'conceal',
#  'concern',
#  'concert',
#  'condit',
#  'conduct',
#  'confer',
#  'confess',
#  'confisc',
#  'confront',
#  'congratul',
#  'connect',
#  'conquer',
#  'consid',
#  'constant',
#  'contact',
#  'contain',
#  'content',
#  'continu',
#  'control',
#  'convers',
#  'convinc',
#  'cool',
#  'cooper',
#  'cop',
#  'copi',
#  'cordelia',
#  'corner',
#  'corpor',
#  'correct',
#  'corrupt',
#  'count',
#  'countermeasur',
#  'countri',
#  'coupl',
#  'cours',
#  'court',
#  'cousin',
#  'cover',
#  'cowboy',
#  'crash',
#  'crate',
#  'creat',
#  'credit',
#  'crew',
#  'cri',
#  'crime',
#  'crimin',
#  'cross',
#  'curat',
#  'current',
#  'curri',
#  'custom',
#  'cut',
#  'cyril',
#  'danc',
#  'danger',
#  'dare',
#  'dark',
#  'date',
#  'daughter',
#  'dave',
#  'davi',
#  'david',
#  'day',
#  'dea',
#  'dead',
#  'deal',
#  'dealer',
#  'death',
#  'decid',
#  'decker',
#  'deduc',
#  'deed',
#  'deever',
#  'defeat',
#  'degre',
#  'deject',
#  'deliber',
#  'delight',
#  'deliv',
#  'demand',
#  'depart',
#  'dermott',
#  'desert',
#  'design',
#  'desk',
#  'desolnay',
#  'desper',
#  'despit',
#  'destroy',
#  'detect',
#  'determin',
#  'devast',
#  'develop',
#  'dex',
#  'diamond',
#  'diaz',
#  'did',
#  'die',
#  'diego',
#  'diego-suarez',
#  'differ',
#  'dine',
#  'dinner',
#  'direct',
#  'director',
#  'disapprov',
#  'disciplin',
#  'discov',
#  'disguis',
#  'disgust',
#  'dislik',
#  'dismay',
#  'display',
#  'distract',
#  'distress',
#  'disturb',
#  'doctor',
#  'document',
#  'doe',
#  'dog',
#  'dollar',
#  'don',
#  'donald',
#  'doofi',
#  'door',
#  'doubt',
#  'downstair',
#  'dr',
#  'drag',
#  'draw',
#  'dress',
#  'drew',
#  'drink',
#  'drive',
#  'drop',
#  'drown',
#  'drug',
#  'duel',
#  'dumbfound',
#  'dump',
#  'dure',
#  'duti',
#  'easi',
#  'eccentr',
#  'edg',
#  'effect',
#  'effort',
#  'elder',
#  'elizabeth',
#  'elliot',
#  'els',
#  'embarrass',
#  'embrac',
#  'emma',
#  'emperor',
#  'empti',
#  'encount',
#  'end',
#  'endang',
#  'enemi',
#  'enforc',
#  'engag',
#  'england',
#  'enjoy',
#  'enter',
#  'entertain',
#  'enthusiasm',
#  'entir',
#  'entri',
#  'episod',
#  'errand',
#  'escap',
#  'escort',
#  'especi',
#  'estrang',
#  'europ',
#  'event',
#  'eventu',
#  'everi',
#  'everyon',
#  'everyth',
#  'evid',
#  'exact',
#  'examin',
#  'exasper',
#  'exchang',
#  'excit',
#  'execut',
#  'exhibit',
#  'exist',
#  'expect',
#  'expedit',
#  'expens',
#  'explain',
#  'explan',
#  'explod',
#  'explor',
#  'explos',
#  'expos',
#  'express',
#  'extend',
#  'eye',
#  'fabian',
#  'face',
#  'fact',
#  'fail',
#  'failur',
#  'fake',
#  'fall',
#  'fals',
#  'famili',
#  'famous',
#  'farrel',
#  'father',
#  'favor',
#  'fear',
#  'featur',
#  'feel',
#  'fellow',
#  'fiance',
#  'fiction',
#  'field',
#  'fight',
#  'figler',
#  'file',
#  'film',
#  'final',
#  'financi',
#  'fine',
#  'finger',
#  'finish',
#  'firefight',
#  'fireplac',
#  'fish',
#  'fit',
#  'flee',
#  'flint',
#  'floor',
#  'follow',
#  'fool',
#  'foot',
#  'footbal',
#  'footprint',
#  'forb',
#  'forc',
#  'forg',
#  'forger',
#  'forgeri',
#  'form',
#  'formal',
#  'formid',
#  'fort',
#  'franc',
#  'franck',
#  'frank',
#  'fraud',
#  'free',
#  'freedom',
#  'friend',
#  'friendship',
#  'frozen',
#  'fruit',
#  'fund',
#  'furious',
#  'gail',
#  'gala',
#  'gambl',
#  'game',
#  'gang',
#  'garfield',
#  'gari',
#  'garrett',
#  'garri',
#  'gather',
#  'gave',
#  'gay',
#  'gentl',
#  'georg',
#  'german',
#  'germani',
#  'gestapo',
#  'gestur',
#  'ghent',
#  'ghost',
#  'gift',
#  'gil',
#  'girl',
#  'given',
#  'glass',
#  'glove',
#  'goe',
#  'gogh',
#  'gold',
#  'gomez',
#  'gone',
#  'good',
#  'googin',
#  'governor',
#  'grab',
#  'grace',
#  'graduat',
#  'grammont',
#  'grand',
#  'grandfath',
#  'grandson',
#  'granger',
#  'grant',
#  'great',
#  'greenberg',
#  'greet',
#  'greg',
#  'gregorius',
#  'ground',
#  'group',
#  'grow',
#  'gruber',
#  'grumbl',
#  'guard',
#  'guest',
#  'guid',
#  'guild',
#  'guilti',
#  'gun',
#  'gunn',
#  'guy',
#  'gym',
#  'hailstorm',
#  'half',
#  'halfway',
#  'hand',
#  'handsom',
#  'hang',
#  'hantz',
#  'happen',
#  'happi',
#  'har',
#  'harbour',
#  'harri',
#  'harsh',
#  'hassert',
#  'hat',
#  'hawk',
#  'hawkin',
#  'hay',
#  'head',
#  'hear',
#  'heard',
#  'heartbroken',
#  'held',
#  'helen',
#  'helicopt',
#  'help',
#  'henri',
#  'hesit',
#  'hidden',
#  'hide',
#  'high',
#  'hire',
#  'hispaniola',
#  'histori',
#  'hit',
#  'hitih',
#  'hitler',
#  'hms',
#  'hold',
#  'hole',
#  'home',
#  'honest',
#  'honeymoon',
#  'honor',
#  'hook',
#  'hope',
#  'horror',
#  'hospit',
#  'host',
#  'hot',
#  'hotel',
#  'hour',
#  'hous',
#  'howev',
#  'huge',
#  'hugh',
#  'human',
#  'hunt',
#  'hurri',
#  'husband',
#  'ice',
#  'idea',
#  'ident',
#  'identifi',
#  'idl',
#  'immedi',
#  'imprison',
#  'includ',
#  'indign',
#  'industrialist',
#  'inform',
#  'initi',
#  'innsbruck',
#  'inquir',
#  'insid',
#  'insist',
#  'instant',
#  'instead',
#  'instruct',
#  'insur',
#  'intellig',
#  'intend',
#  'intent',
#  'interior',
#  'intern',
#  'interrupt',
#  'introduc',
#  'intrud',
#  'invest',
#  'investig',
#  'invit',
#  'involv',
#  'irrit',
#  'island',
#  'israel',
#  'issu',
#  'itali',
#  'item',
#  'jeff',
#  'jeffri',
#  'jet',
#  'jewel',
#  'jim',
#  'job',
#  'john',
#  'johnni',
#  'join',
#  'jonathan',
#  'joseph',
#  'judi',
#  'juli',
#  'just',
#  'justin',
#  'k2',
#  'kareem',
#  'karen',
#  'kasen',
#  'kept',
#  'kevin',
#  'key',
#  'khan',
#  'kid',
#  'kidnap',
#  'kill',
#  'killer',
#  'kind',
#  'king',
#  'kiss',
#  'knapp',
#  'knew',
#  'knife',
#  'knock',
#  'know',
#  'known',
#  'kovich',
#  'krasna',
#  'kristo',
#  'kruger',
#  'kublai',
#  'kukachin',
#  'lack',
#  'ladies-in-wait',
#  'lanc',
#  'land',
#  'larri',
#  'late',
#  'later',
#  'latest',
#  'laugh',
#  'lautrec',
#  'law',
#  'lay',
#  'lead',
#  'leader',
#  'leadership',
#  'learn',
#  'leav',
#  'leaves.th',
#  'led',
#  'left',
#  'leg',
#  'legal',
#  'leland',
#  'leon',
#  'let',
#  'lewi',
#  'licenc',
#  'lie',
#  'life',
#  'light',
#  'like',
#  'limit',
#  'link',
#  'liszt',
#  'littl',
#  'live',
#  'livesey',
#  'll',
#  'lobbi',
#  'local',
#  'locat',
#  'lock',
#  'locker',
#  'london',
#  'long',
#  'longer',
#  'look',
#  'loot',
#  'lose',
#  'loss',
#  'lost',
#  'louis',
#  'love',
#  'lover',
#  'luci',
#  'lung',
#  'lure',
#  'macdougal',
#  'mackenzi',
#  'mad',
#  'madonna',
#  'mafia',
#  'magnet',
#  'maimiti',
#  'main',
#  'maintain',
#  'make',
#  'malcolm',
#  'man',
#  'manag',
#  'mani',
#  'manner',
#  'map',
#  'marco',
#  'mari',
#  'maria',
#  'marijuana',
#  'marmalad',
#  'maroon',
#  'marri',
#  'marriag',
#  'marti',
#  'martin',
#  'martinez',
#  'mask',
#  'master',
#  'masterpiec',
#  'match',
#  'matter',
#  'mayama',
#  'meal',
#  'mean',
#  'meanwhil',
#  'medallion',
#  'media',
#  'medic',
#  'meet',
#  'meg',
#  'member',
#  'men',
#  'mendez',
#  'mendoza',
#  'mention',
#  'mere',
#  'mespelbrunn',
#  'met',
#  'method',
#  'michael',
#  'michelangelo',
#  'middl',
#  'midnight',
#  'miguel',
#  'mika',
#  'millic',
#  'million',
#  'mind',
#  'minist',
#  'minor',
#  'minut',
#  'miss',
#  'mission',
#  'mistak',
#  'model',
#  'moghul',
#  'moment',
#  'money',
#  'moniqu',
#  'monkey',
#  'monsieur',
#  'mont',
#  'montgomeri',
#  'month',
#  'mop',
#  'morn',
#  'mother',
#  'motiv',
#  'mountain',
#  'movi',
#  'mr',
#  'mrs',
#  'murder',
#  'museum',
#  'music',
#  'mustach',
#  'mutini',
#  'mysteri',
#  "n't",
#  'nathan',
#  'natur',
#  'naval',
#  'navi',
#  'nazi',
#  'near',
#  'necklac',
#  'need',
#  'neglect',
#  'neighborhood',
#  'new',
#  'news',
#  'newspap',
#  'nice',
#  'nich',
#  'nicol',
#  'night',
#  'nightclub',
#  'nighti',
#  'nikola',
#  'nina',
#  'nitro',
#  'nitroglycerin',
#  'nobodi',
#  'nois',
#  'normal',
#  'nose',
#  'note',
#  'noth',
#  'notic',
#  'novick',
#  'number',
#  'observ',
#  'obtain',
#  'occupi',
#  'occur',
#  'odd',
#  'off-duti',
#  'offer',
#  'offic',
#  'offici',
#  'oh',
#  'old',
#  'older',
#  'onc',
#  'onli',
#  'open',
#  'oper',
#  'opi',
#  'opportun',
#  'order',
#  'ordinari',
#  'organis',
#  'otto',
#  'outsid',
#  'overse',
#  'owe',
#  'owen',
#  'owner',
#  'oxford',
#  'pack',
#  'packet',
#  'paddington',
#  'paint',
#  'pair',
#  'pakistan',
#  'palac',
#  'pandora',
#  'panel',
#  'papa',
#  'paravideo',
#  'parcel',
#  'parent',
#  'pari',
#  'park',
#  'parti',
#  'particular',
#  'partner',
#  'pass',
#  'passag',
#  'pastuzo',
#  ...]

# %% [markdown]
# Compute distance using Cosine Similarity
# > Cosine Similarity is measured using the tf-idf matrix to generate a measure of similarity between each movie plot and the other move plots in the input data

# %%
from sklearn.metrics.pairwise import cosine_similarity
dist = 1 - cosine_similarity(tfidf_matrix)

# %%
dist.shape
# Out:
# (20552, 20552)

# %% [markdown]
# ### 5. K-means clustering
